# %%
pip install seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="object")
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.histplot(iris["petal_length"],bins = 20)
plt.show()

# %%
# kde-plot -- kernel density plot

# %%
sns.kdeplot(iris["petal_length"])
plt.show()

# %%
sns.scatterplot(x=iris["petal_length"],y = iris["petal_width"],data = iris , hue = "species")
plt.show()

# %%
sns.jointplot(x="petal_length",y = "petal_width",data= iris )
plt.show()

# %%
sns.jointplot(x="petal_length",y = "petal_width",data= iris,kind = "kde" )
plt.show()

# %%
sns.jointplot(x="petal_length",y = "petal_width",data= iris,hue = "species" )
plt.show()

# %%
sns.pairplot(data = iris, hue = "species")
plt.show()

# %%
sns.countplot(x="species",data = iris)
plt.show()

# %%
sns.boxplot(x="species",y = "sepal_length",data = iris, color = "r")
plt.show()

# %%
sns.violinplot(x="species",y = "sepal_length",data = iris)
plt.show()

# %%
iris.corr()
# Out:
# <ipython-input-35-156dd03bc859>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(),cmap="Blues",annot = True)
plt.show()
# Out:
# <ipython-input-39-092d5b7e0e84>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),cmap="Blues",annot = True)

# %%
# Choosing the right visualization/plot

# %%
# what is the right chart to use to find dependency between
# one continous variable and categorical variable

# %%
#1D viz -- one variable -- num distribution (hist,kde,boxplot),categorical ,count(barplot,countplot)
#2D viz --  two variables -- num-num (scaterplot),cat-cat(??),cat-num(barplot,boxplot,violin)
#2D viz - multiple  variables -- pairplot,heatmap
#Multi-dimensional viz -- scaterplot with hue (color coding),num-num categorical,surface plot

# %%
#1D plots

# %%
sns.histplot(iris["sepal_length"],bins = 20)
plt.show()

# %%
sns.boxplot(y="sepal_length",data = iris)
plt.show()

# %%
sns.countplot(x="species",data= iris,hue = "species")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.lineplot(x = "sepal_length", y = "petal_width", data=iris)
plt.show()

# %%
sns.boxplot(x="species",y= "sepal_length",data= iris,hue = "species")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
tips = sns.load_dataset("tips")

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.countplot(x = "day",data=tips,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# two categoricals, and one numericals-day,time,total_time

# %%
sns.barplot(x = "day",y = "total_bill",hue = "time",data= tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
